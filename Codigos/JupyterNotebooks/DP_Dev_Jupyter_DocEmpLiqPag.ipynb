# %% [markdown]
# ## ----------------------------------- Projeto Cetus --------------------------------------------
# ## Assunto: Documentos de empenho, liquidação e pagamento
# ## Defasagem: D-2

# %%
# Autor: Bruno Jardim | Rauhe Abdulhamid
# Data: 02/03/2019
# Descrição: Código para salvar os dados do portal transparência no datalake (AWS - S3)
# URL: http://www.portaltransparencia.gov.br/download-de-dados

# %%
ANOMES_INFO = 20140516
import urllib.request
urllib.request.urlretrieve('http://www.portaltransparencia.gov.br/download-de-dados/despesas/'+str(ANOMES_INFO), 'dados_despesaspub_' + str(ANOMES_INFO) + '.zip')

import zipfile
with zipfile.ZipFile('dados_despesaspub_' + str(ANOMES_INFO) + '.zip',"r") as zip_ref:
    zip_ref.extractall('dados_despesaspub_' + str(ANOMES_INFO))

# %%
nm_file1 = str(ANOMES_INFO)+'_Despesas_Empenho.csv'
nm_file2 = str(ANOMES_INFO)+'_Despesas_ItemEmpenho.csv'
nm_file3 = str(ANOMES_INFO)+'_Despesas_Liquidacao.csv'
nm_file4 = str(ANOMES_INFO)+'_Despesas_Liquidacao_EmpenhosImpactados.csv'
nm_file5 = str(ANOMES_INFO)+'_Despesas_Pagamento.csv'
nm_file6 = str(ANOMES_INFO)+'_Despesas_Pagamento_EmpenhosImpactados.csv'
nm_file7 = str(ANOMES_INFO)+'_Despesas_Pagamento_ListaFaturas.csv'
nm_file8 = str(ANOMES_INFO)+'_Despesas_Pagamento_FavorecidosFinais.csv'
nm_file9 = str(ANOMES_INFO)+'_Despesas_Pagamento_ListaBancos.csv'
nm_file10 = str(ANOMES_INFO)+'_Despesas_Pagamento_ListaPrecatorios.csv'

# %%
#-----------------------  EMPENHO ------------------------------
import pandas as pd
import chardet
with open('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file1, 'rb') as f:
    result = chardet.detect(f.readline())  # or readline if the file is large
df_empenho = pd.read_csv('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file1, encoding=result['encoding'], error_bad_lines=False,sep=';', engine='python')

df_empenho['DT_INFO'] = ANOMES_INFO
df_empenho['PK_NMR_DPS'] = df_empenho['Id Empenho']


#-----------------------  ITEM EMPENHO ------------------------------
with open('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file2, 'rb') as f:
    result = chardet.detect(f.readline())  # or readline if the file is large
df_iempenho = pd.read_csv('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file2, encoding=result['encoding'], error_bad_lines=False,sep=';', engine='python')
df_iempenho['DT_INFO'] = ANOMES_INFO
df_iempenho['PK_NMR_DPS'] = df_iempenho['Id Empenho']


#-----------------------  LIQUIDAÇÃO  ------------------------------
with open('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file3, 'rb') as f:
    result = chardet.detect(f.readline())  # or readline if the file is large
df_liquidacao = pd.read_csv('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file3, encoding=result['encoding'], error_bad_lines=False,sep=';', engine='python')
df_liquidacao['DT_INFO'] = ANOMES_INFO
df_liquidacao['PK_NMR_DPS'] = df_liquidacao['Código Liquidação']


#-----------------------  LIQUIDAÇÃO EMPENHOS IMPACTADOS ------------------------------
with open('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file4, 'rb') as f:
    result = chardet.detect(f.readline())  # or readline if the file is large
df_liquidacaoemp = pd.read_csv('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file4, encoding=result['encoding'], error_bad_lines=False,sep=';', engine='python')
df_liquidacaoemp['DT_INFO'] = ANOMES_INFO
df_liquidacaoemp['PK_NMR_DPS'] = df_liquidacaoemp['Código Liquidação']


#-----------------------  PAGAMENTO ------------------------------
with open('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file5, 'rb') as f:
    result = chardet.detect(f.readline())  # or readline if the file is large
df_pagamento = pd.read_csv('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file5, encoding=result['encoding'], error_bad_lines=False,sep=';', engine='python')
df_pagamento['DT_INFO'] = ANOMES_INFO
df_pagamento['PK_NMR_DPS'] = df_pagamento['Código Pagamento']


#-----------------------  PAGAMENTO EMPENHOS IMPACTADOS ------------------------------
with open('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file6, 'rb') as f:
    result = chardet.detect(f.readline())  # or readline if the file is large
df_pagamentoemp = pd.read_csv('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file6, encoding=result['encoding'], error_bad_lines=False,sep=';', engine='python')
df_pagamentoemp['DT_INFO'] = ANOMES_INFO
df_pagamentoemp['PK_NMR_DPS'] = df_pagamentoemp['Código Pagamento']



#-----------------------  PAGAMENTO LISTA FATURAS ------------------------------
with open('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file7, 'rb') as f:
    result = chardet.detect(f.readline())  # or readline if the file is large
df_pagamentolistas = pd.read_csv('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file7, encoding=result['encoding'], error_bad_lines=False,sep=';', engine='python')
df_pagamentolistas['DT_INFO'] = ANOMES_INFO
df_pagamentolistas['PK_NMR_DPS'] = df_pagamentolistas['Código Pagamento']


#-----------------------  PAGAMENTO FAVORECIDOS FINAIS ------------------------------
with open('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file8, 'rb') as f:
    result = chardet.detect(f.readline())  # or readline if the file is large
df_pagamentofav = pd.read_csv('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file8, encoding=result['encoding'], error_bad_lines=False,sep=';', engine='python')
df_pagamentofav['DT_INFO'] = ANOMES_INFO
df_pagamentofav['PK_NMR_DPS'] = df_pagamentofav['Código Pagamento']


#-----------------------  PAGAMENTO LISTA BANCOS ------------------------------
with open('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file9, 'rb') as f:
    result = chardet.detect(f.readline())  # or readline if the file is large
df_pagamentobancos = pd.read_csv('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file9, encoding=result['encoding'], error_bad_lines=False,sep=';', engine='python')
df_pagamentobancos['DT_INFO'] = ANOMES_INFO
df_pagamentobancos['PK_NMR_DPS'] = df_pagamentobancos['Código Pagamento']


#-----------------------  PAGAMENTO LISTA PRECATÓRIOS ------------------------------
with open('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file10, 'rb') as f:
    result = chardet.detect(f.readline())  # or readline if the file is large
df_pagamentoprecatorios = pd.read_csv('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file10, encoding=result['encoding'], error_bad_lines=False,sep=';', engine='python')
df_pagamentoprecatorios['DT_INFO'] = ANOMES_INFO
df_pagamentoprecatorios['PK_NMR_DPS'] = df_pagamentoprecatorios['Código Pagamento']

# %%
df_empenho.head()
# Out:
#    Id Empenho           Código Empenho Código Empenho Resumido Data Emissão  \
# 0    22542702  160422000012014NE800232            2014NE800232   16/05/2014
# 1    15251242  110581000012014NE000115            2014NE000115   16/05/2014
# 2    29606643  158264264192014NE000143            2014NE000143   16/05/2014
# 3    14696023  153164152382014NE400886            2014NE400886   16/05/2014
# 4    20763328  158494264142014NE000329            2014NE000329   16/05/2014
#
#   Código Tipo Documento   Tipo Documento Tipo Empenho Espécie Empenho  \
# 0                    NE  Nota de Empenho       Global        ORIGINAL
# 1                    NE  Nota de Empenho   Estimativo        ANULAÇÃO
# 2                    NE  Nota de Empenho   Estimativo        ORIGINAL
# 3                    NE  Nota de Empenho   Estimativo         REFORÇO
# 4                    NE  Nota de Empenho    Ordinário        ORIGINAL
#
#    Código Órgão Superior            Órgão Superior     ...      Inciso  \
# 0                  52000      MINISTERIO DA DEFESA     ...          02
# 1                  63000  ADVOCACIA-GERAL DA UNIAO     ...         NaN
# 2                  26000    MINISTERIO DA EDUCACAO     ...         NaN
# 3                  26000    MINISTERIO DA EDUCACAO     ...         NaN
# 4                  26000    MINISTERIO DA EDUCACAO     ...         NaN
#
#      Amparo  Referência de Dispensa ou Inexigibilidade Código Convênio  \
# 0  LEI 8666                       ART24/02 LEI 8666/93             NaN
# 1       NaN                                        NaN             NaN
# 2       NaN                                        NaN             NaN
# 3       NaN                                        NaN             NaN
# 4       NaN                                        NaN             NaN
#
#    Contrato de Repasse / Termo de Parceria / Outros Valor Original do Empenho  \
# 0                                               NaN                   2400,00
# 1                                               NaN                   8000,00
# 2                                               NaN                   9000,00
# 3                                               NaN                   6250,00
# 4                                               NaN                   1200,00
#
#   Valor do Empenho Convertido pra R$ Valor Utilizado na Conversão   DT_INFO  \
# 0                            2400,00                       1,0000  20140516
# 1                            8000,00                       1,0000  20140516
# 2                            9000,00                       1,0000  20140516
# 3                            6250,00                       1,0000  20140516
# 4                            1200,00                       1,0000  20140516
#
#    PK_NMR_DPS
# 0    22542702
# 1    15251242
# 2    29606643
# 3    14696023
# 4    20763328
#
# [5 rows x 63 columns]

# %%
df_iempenho.head()
# Out:
#    Id Empenho           Código Empenho Código Categoria de Despesa  \
# 0    62402220  170184000012019NE800009                           3
# 1    62402255  170182000012019NE800006                           3
# 2    62402394  170180000012019NE800007                           3
# 3    62402542  158393264232019NE800008                           3
# 4    62402542  158393264232019NE800008                           3
#
#   Categoria de Despesa Código Grupo de Despesa           Grupo de Despesa  \
# 0   DESPESAS CORRENTES                       3  OUTRAS DESPESAS CORRENTES
# 1   DESPESAS CORRENTES                       3  OUTRAS DESPESAS CORRENTES
# 2   DESPESAS CORRENTES                       3  OUTRAS DESPESAS CORRENTES
# 3   DESPESAS CORRENTES                       3  OUTRAS DESPESAS CORRENTES
# 4   DESPESAS CORRENTES                       3  OUTRAS DESPESAS CORRENTES
#
#    Código Modalidade de Aplicação Modalidade de Aplicação  \
# 0                              90      APLICACOES DIRETAS
# 1                              90      APLICACOES DIRETAS
# 2                              90      APLICACOES DIRETAS
# 3                              90      APLICACOES DIRETAS
# 4                              90      APLICACOES DIRETAS
#
#    Código Elemento de Despesa                            Elemento de Despesa  \
# 0                          40  SERVIÇOS DE TECNOLOGIA DA INFORMAÇÃO E COMUNI
# 1                          39  OUTROS SERVICOS DE TERCEIROS - PESSOA JURIDIC
# 2                          39  OUTROS SERVICOS DE TERCEIROS - PESSOA JURIDIC
# 3                          37                         LOCACAO DE MAO-DE-OBRA
# 4                          37                         LOCACAO DE MAO-DE-OBRA
#
#    Código SubElemento de Despesa  \
# 0                              5
# 1                             78
# 2                             77
# 3                              3
# 4                              3
#
#                          SubElemento de Despesa  \
# 0    LOCACAO DE EQUIPAMENTOS DE TIC - TELEFONIA
# 1                         LIMPEZA E CONSERVACAO
# 2  VIGILANCIA OSTENSIVA/MONITORADA/RASTREAMENTO
# 3                          VIGILANCIA OSTENSIVA
# 4                          VIGILANCIA OSTENSIVA
#
#                                            Descrição Quantidade  \
# 0  INSTALACAO / MANUTENCAO / EXPANSAO / PROGRAMAC...   13,00000
# 1  PRESTACAO DE SERVICO DE LIMPEZA E CONSERVACAO ...    1,00000
# 2  SERVICO DE VIGILANCIA ARMADA                  ...    1,00000
# 3  SERVICO DE VIGILANCIA ARMADA                  ...    1,00000
# 4  SERVICO DE VIGILANCIA ARMADA                  ...    1,00000
#
#   Valor Unitário   Valor Total   DT_INFO  PK_NMR_DPS
# 0         ,07000        ,91000  20190101    62402220
# 1        5,00000       5,00000  20190101    62402255
# 2   119432,17000  119432,17000  20190101    62402394
# 3    49217,00000   49217,00000  20190101    62402542
# 4    39108,00000   39108,00000  20190101    62402542

# %%
df_liquidacao.head()
# Out:
#          Código Liquidação Código Liquidação Resumido Data Emissão  \
# 0  155001152752019NS016417               2019NS016417   01/01/2019
# 1  158392264232019NS000152               2019NS000152   01/01/2019
# 2  764000000012019NS000010               2019NS000010   01/01/2019
# 3  158128264082019NS000391               2019NS000391   01/01/2019
# 4  158413264112019NS000031               2019NS000031   01/01/2019
#
#   Código Tipo Documento                 Tipo Documento  Código Órgão Superior  \
# 0                    NS  Nota de Lançamento de Sistema                  26000
# 1                    NS  Nota de Lançamento de Sistema                  26000
# 2                    NS  Nota de Lançamento de Sistema                  52000
# 3                    NS  Nota de Lançamento de Sistema                  26000
# 4                    NS  Nota de Lançamento de Sistema                  26000
#
#            Órgão Superior  Código Órgão  \
# 0  Ministério da Educação         26294
# 1  Ministério da Educação         26423
# 2    Ministério da Defesa         52131
# 3  Ministério da Educação         26408
# 4  Ministério da Educação         26411
#
#                                            Órgão  Código Unidade Gestora  \
# 0           Hospital de Clínicas de Porto Alegre                  155001
# 1  Instituto Federal de Educação, Ciência e Tecn                  158392
# 2                             Comando da Marinha                  764000
# 3  Instituto Federal de Educação, Ciência e Tecn                  158128
# 4  Instituto Federal de Educação, Ciência e Tecn                  158413
#
#             ...            Código Categoria de Despesa  Categoria de Despesa  \
# 0           ...                                      3    DESPESAS CORRENTES
# 1           ...                                      4   DESPESAS DE CAPITAL
# 2           ...                                      4   DESPESAS DE CAPITAL
# 3           ...                                      4   DESPESAS DE CAPITAL
# 4           ...                                     MU              Múltiplo
#
#   Código Grupo de Despesa           Grupo de Despesa  \
# 0                       3  Outras Despesas Correntes
# 1                       4              Investimentos
# 2                       4              Investimentos
# 3                       4              Investimentos
# 4                      MU                   Múltiplo
#
#   Código Modalidade de Aplicação  Modalidade de Aplicação  \
# 0                             90  Reserva de Contingência
# 1                             90  Reserva de Contingência
# 2                             90  Reserva de Contingência
# 3                             90  Reserva de Contingência
# 4                             MU                 Múltiplo
#
#   Código Elemento de Despesa                 Elemento de Despesa   DT_INFO  \
# 0                         30                 Material de Consumo  20190101
# 1                         52  Equipamentos e Material Permanente  20190101
# 2                         52  Equipamentos e Material Permanente  20190101
# 3                         52  Equipamentos e Material Permanente  20190101
# 4                         MU                            Múltiplo  20190101
#
#                 PK_NMR_DPS
# 0  155001152752019NS016417
# 1  158392264232019NS000152
# 2  764000000012019NS000010
# 3  158128264082019NS000391
# 4  158413264112019NS000031
#
# [5 rows x 26 columns]

# %%
df_liquidacaoemp.head()
# Out:
#          Código Liquidação           Código Empenho Valor Liquidado (R$)  \
# 0  135039132032019NS000149  135039132032018NE000134                 0,00
# 1  135554222112019NS000020  135554222112018NE000012                 0,00
# 2  135554222112019NS000021  135554222112018NE000012                 0,00
# 3  135587222112019NS000009  135587222112019NE000004               855,65
# 4  153114152352019NS000084  153114152352018NE000006                 0,00
#
#   Valor Restos a Pagar Inscritos (R$) Valor Restos a Pagar Cancelado (R$)  \
# 0                                0,00                              101,14
# 1                                0,00                                0,00
# 2                                0,00                                0,00
# 3                                0,00                                0,00
# 4                                0,00                                0,00
#
#   Valor Restos a Pagar Pagos (R$)   DT_INFO               PK_NMR_DPS
# 0                            0,00  20190101  135039132032019NS000149
# 1                            0,00  20190101  135554222112019NS000020
# 2                            0,00  20190101  135554222112019NS000021
# 3                            0,00  20190101  135587222112019NS000009
# 4                            0,00  20190101  153114152352019NS000084

# %%
df_pagamento.head()
# Out:
#           Código Pagamento Código Pagamento Resumido Data Emissão  \
# 0  155001152752019NS004348              2019NS004348   01/01/2019
#
#   Código Tipo Documento                 Tipo Documento        Tipo OB  \
# 0                    NS  Nota de Lançamento de Sistema  Não se aplica
#
#   Extraorçamentário  Código Órgão Superior          Órgão Superior  \
# 0               NÃO                  26000  Ministério da Educação
#
#    Código Órgão           ...                      Grupo de Despesa  \
# 0         26294           ...             Outras Despesas Correntes
#
#    Código Modalidade de Aplicação  Modalidade de Aplicação  \
# 0                              90  Reserva de Contingência
#
#    Código Elemento de Despesa Elemento de Despesa Valor Original do Pagamento  \
# 0                          MU            Múltiplo                     2000,00
#
#   Valor do Pagamento Convertido pra R$ Valor Utilizado na Conversão   DT_INFO  \
# 0                              2000,00                       1,0000  20190101
#
#                 PK_NMR_DPS
# 0  155001152752019NS004348
#
# [1 rows x 32 columns]

# %%
df_pagamentoemp.head()
# Out:
#           Código Pagamento           Código Empenho Valor Pago (R$)  \
# 0  155001152752019NS004348  155001152752019NE504992         1900,00
# 1  155001152752019NS004348  155001152752019NE504994          100,00
#
#   Valor Restos a Pagar Inscritos (R$) Valor Restos a Pagar Cancelado (R$)  \
# 0                                0,00                                0,00
# 1                                0,00                                0,00
#
#   Valor Restos a Pagar Pagos (R$)   DT_INFO               PK_NMR_DPS
# 0                            0,00  20190101  155001152752019NS004348
# 1                            0,00  20190101  155001152752019NS004348

# %%
df_pagamentolistas.head()
# Out:
# Empty DataFrame
# Columns: [Código Pagamento, Código Lista, Data Emissão, Código Sequência, Valor Lançamento em R$, Valor Desconto em R$, Valor Juros em R$, Valor Dedução em R$, Valor Acréscimo em R$, DT_INFO, PK_NMR_DPS]
# Index: []

# %%
df_pagamentofav.head()
# Out:
# Empty DataFrame
# Columns: [Código Pagamento, Código Lista, Data Emissão, Código Favorecido, Favorecido, Valor do Pagamento em R$, DT_INFO, PK_NMR_DPS]
# Index: []

# %%
df_pagamentobancos.head()
# Out:
# Empty DataFrame
# Columns: [Código Pagamento, Código Lista, Data Emissão, Código Banco, Nome Banco, Agência, Valor em R$, DT_INFO, PK_NMR_DPS]
# Index: []

# %%
df_pagamentoprecatorios.head()
# Out:
# Empty DataFrame
# Columns: [Código Pagamento, Código Lista, Data Emissão, Número Parcela, Valor Precatorio em R$, DT_INFO, PK_NMR_DPS]
# Index: []

# %%
df_empenho.shape, df_iempenho.shape, df_liquidacao.shape, df_liquidacaoemp.shape, df_pagamento.shape, df_pagamentoemp.shape, df_pagamentolistas.shape, df_pagamentofav.shape, df_pagamentobancos.shape, df_pagamentoprecatorios.shape
# Out:
# ((12487, 63),
#  (21490, 18),
#  (23765, 26),
#  (26429, 8),
#  (36046, 32),
#  (33804, 8),
#  (2557, 11),
#  (22910, 8),
#  (0, 9),
#  (94, 7))

# %%
# Função pra pegar várias datas

def CetusDespesasPublicas(ANOMES_INFO):
    #ANOMES_INFO = 20130331
    import urllib.request
    urllib.request.urlretrieve('http://www.portaltransparencia.gov.br/download-de-dados/despesas/'+str(ANOMES_INFO), 'dados_despesaspub_' + str(ANOMES_INFO) + '.zip')

    import zipfile

    with zipfile.ZipFile('dados_despesaspub_' + str(ANOMES_INFO) + '.zip',"r") as zip_ref:
    
        zip_ref.extractall('dados_despesaspub_' + str(ANOMES_INFO))  
    
        nm_file1 = str(ANOMES_INFO)+'_Despesas_Empenho.csv'
        nm_file2 = str(ANOMES_INFO)+'_Despesas_ItemEmpenho.csv'
        nm_file3 = str(ANOMES_INFO)+'_Despesas_Liquidacao.csv'
        nm_file4 = str(ANOMES_INFO)+'_Despesas_Liquidacao_EmpenhosImpactados.csv'
        nm_file5 = str(ANOMES_INFO)+'_Despesas_Pagamento.csv'
        nm_file6 = str(ANOMES_INFO)+'_Despesas_Pagamento_EmpenhosImpactados.csv'
        nm_file7 = str(ANOMES_INFO)+'_Despesas_Pagamento_ListaFaturas.csv'
        nm_file8 = str(ANOMES_INFO)+'_Despesas_Pagamento_FavorecidosFinais.csv'
        nm_file9 = str(ANOMES_INFO)+'_Despesas_Pagamento_ListaBancos.csv'
        nm_file10 = str(ANOMES_INFO)+'_Despesas_Pagamento_ListaPrecatorios.csv'

    #-----------------------  EMPENHO ------------------------------
    import pandas as pd
    import chardet
    with open('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file1, 'rb') as f:
        result = chardet.detect(f.readline())  # or readline if the file is large
    df_empenho = pd.read_csv('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file1, encoding=result['encoding'], error_bad_lines=False,sep=';', engine='python')
    df_empenho['DT_INFO'] = ANOMES_INFO
    df_empenho['PK_NMR_DPS'] = df_empenho['Id Empenho']


    #-----------------------  ITEM EMPENHO ------------------------------
    with open('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file2, 'rb') as f:
        result = chardet.detect(f.readline())  # or readline if the file is large
    df_iempenho = pd.read_csv('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file2, encoding=result['encoding'], error_bad_lines=False,sep=';', engine='python')
    df_iempenho['DT_INFO'] = ANOMES_INFO
    df_iempenho['PK_NMR_DPS'] = df_iempenho['Id Empenho']


    #-----------------------  LIQUIDAÇÃO  ------------------------------
    with open('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file3, 'rb') as f:
        result = chardet.detect(f.readline())  # or readline if the file is large
    df_liquidacao = pd.read_csv('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file3, encoding=result['encoding'], error_bad_lines=False,sep=';', engine='python')
    df_liquidacao['DT_INFO'] = ANOMES_INFO
    df_liquidacao['PK_NMR_DPS'] = df_liquidacao['Código Liquidação']


    #-----------------------  LIQUIDAÇÃO EMPENHOS IMPACTADOS ------------------------------
    with open('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file4, 'rb') as f:
        result = chardet.detect(f.readline())  # or readline if the file is large
    df_liquidacaoemp = pd.read_csv('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file4, encoding=result['encoding'], error_bad_lines=False,sep=';', engine='python')
    df_liquidacaoemp['DT_INFO'] = ANOMES_INFO
    df_liquidacaoemp['PK_NMR_DPS'] = df_liquidacaoemp['Código Liquidação']


    #-----------------------  PAGAMENTO ------------------------------
    with open('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file5, 'rb') as f:
        result = chardet.detect(f.readline())  # or readline if the file is large
    df_pagamento = pd.read_csv('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file5, encoding=result['encoding'], error_bad_lines=False,sep=';', engine='python')
    df_pagamento['DT_INFO'] = ANOMES_INFO
    df_pagamento['PK_NMR_DPS'] = df_pagamento['Código Pagamento']


    #-----------------------  PAGAMENTO EMPENHOS IMPACTADOS ------------------------------
    with open('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file6, 'rb') as f:
        result = chardet.detect(f.readline())  # or readline if the file is large
    df_pagamentoemp = pd.read_csv('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file6, encoding=result['encoding'], error_bad_lines=False,sep=';', engine='python')
    df_pagamentoemp['DT_INFO'] = ANOMES_INFO
    df_pagamentoemp['PK_NMR_DPS'] = df_pagamentoemp['Código Pagamento']



    #-----------------------  PAGAMENTO LISTA FATURAS ------------------------------
    with open('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file7, 'rb') as f:
        result = chardet.detect(f.readline())  # or readline if the file is large
    df_pagamentolistas = pd.read_csv('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file7, encoding=result['encoding'], error_bad_lines=False,sep=';', engine='python')
    df_pagamentolistas['DT_INFO'] = ANOMES_INFO
    df_pagamentolistas['PK_NMR_DPS'] = df_pagamentolistas['Código Pagamento']


    #-----------------------  PAGAMENTO FAVORECIDOS FINAIS ------------------------------
    with open('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file8, 'rb') as f:
        result = chardet.detect(f.readline())  # or readline if the file is large
    df_pagamentofav = pd.read_csv('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file8, encoding=result['encoding'], error_bad_lines=False,sep=';', engine='python')
    df_pagamentofav['DT_INFO'] = ANOMES_INFO
    df_pagamentofav['PK_NMR_DPS'] = df_pagamentofav['Código Pagamento']


    #-----------------------  PAGAMENTO LISTA BANCOS ------------------------------
    with open('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file9, 'rb') as f:
        result = chardet.detect(f.readline())  # or readline if the file is large
    df_pagamentobancos = pd.read_csv('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file9, encoding=result['encoding'], error_bad_lines=False,sep=';', engine='python')
    df_pagamentobancos['DT_INFO'] = ANOMES_INFO
    df_pagamentobancos['PK_NMR_DPS'] = df_pagamentobancos['Código Pagamento']


    #-----------------------  PAGAMENTO LISTA PRECATÓRIOS ------------------------------
    with open('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file10, 'rb') as f:
        result = chardet.detect(f.readline())  # or readline if the file is large
    df_pagamentoprecatorios = pd.read_csv('dados_despesaspub_' + str(ANOMES_INFO) +'/' + nm_file10, encoding=result['encoding'], error_bad_lines=False,sep=';', engine='python')
    df_pagamentoprecatorios['DT_INFO'] = ANOMES_INFO
    df_pagamentoprecatorios['PK_NMR_DPS'] = df_pagamentoprecatorios['Código Pagamento']
 
    
    return df_empenho, df_iempenho, df_liquidacao, df_liquidacaoemp, df_pagamento, df_pagamentoemp, df_pagamentolistas, df_pagamentofav, df_pagamentobancos, df_pagamentoprecatorios

# %%
a,b,c,d,e,f,g,h,i,j = CetusDespesasPublicas(20150315)

# %%
a.shape, b.shape, c.shape, d.shape, e.shape, f.shape, g.shape, h.shape, i.shape, j.shape
# Out:
# ((10, 63),
#  (19, 18),
#  (4, 26),
#  (4, 8),
#  (1, 32),
#  (1, 8),
#  (0, 11),
#  (0, 8),
#  (0, 9),
#  (0, 7))

# %%
b.head()
# Out:
#    Id Empenho           Código Empenho  Código Categoria de Despesa  \
# 0    43904510  153165152392015NE000257                            3
# 1    44805841  240056000012015NE000093                            3
# 2    46105775  240056000012015NE000095                            3
# 3    46805588  785331000012015NE000007                            3
# 4    48105248  153019152462015NE000120                            3
#
#   Categoria de Despesa  Código Grupo de Despesa           Grupo de Despesa  \
# 0   DESPESAS CORRENTES                        3  OUTRAS DESPESAS CORRENTES
# 1   DESPESAS CORRENTES                        3  OUTRAS DESPESAS CORRENTES
# 2   DESPESAS CORRENTES                        3  OUTRAS DESPESAS CORRENTES
# 3   DESPESAS CORRENTES                        3  OUTRAS DESPESAS CORRENTES
# 4   DESPESAS CORRENTES                        3  OUTRAS DESPESAS CORRENTES
#
#    Código Modalidade de Aplicação Modalidade de Aplicação  \
# 0                              90      APLICACOES DIRETAS
# 1                              90      APLICACOES DIRETAS
# 2                              90      APLICACOES DIRETAS
# 3                              90      APLICACOES DIRETAS
# 4                              90      APLICACOES DIRETAS
#
#    Código Elemento de Despesa                           Elemento de Despesa  \
# 0                          18               AUXILIO FINANCEIRO A ESTUDANTES
# 1                          39  OUTROS SERVICOS DE TERCEIROS-PESSOA JURIDICA
# 2                          39  OUTROS SERVICOS DE TERCEIROS-PESSOA JURIDICA
# 3                          33            PASSAGENS E DESPESAS COM LOCOMOCAO
# 4                          92             DESPESAS DE EXERCICIOS ANTERIORES
#
#    Código SubElemento de Despesa                 SubElemento de Despesa  \
# 0                              1               BOLSAS DE ESTUDO NO PAIS
# 1                              1  ASSINATURAS DE PERIODICOS E ANUIDADES
# 2                             45                        SERVICOS DE GAS
# 3                              9               TRANSPORTE DE SERVIDORES
# 4                             46                    AUXILIO-ALIMENTACAO
#
#                                            Descrição Quantidade  \
# 0  IMPORTANCIA EMPENHADA A FIM DE PROVER DESPESAS...    1,00000
# 1  EMPENHO PARA ATENDER DESPESA COM ASSINATURA DO...    1,00000
# 2  EMPENHO PARA ATENDER DESPESA COM FORNECIMENTO ...    1,00000
# 3  DESPESAS COM TRANSPORTE AÉREO, TRECHO POA X RJ...    1,00000
# 4                               AUXILIO ALIEMENTACAO    1,00000
#
#   Valor Unitário Valor Total   DT_INFO  PK_NMR_DPS
# 0      290,00000   290,00000  20150315    43904510
# 1       14,99000    14,99000  20150315    44805841
# 2     3981,60000  3981,60000  20150315    46105775
# 3     3045,01000  3045,01000  20150315    46805588
# 4      127,16000   127,16000  20150315    48105248

# %%
def CetusRefVecDays(inicio,fim):
     import datetime
     start = datetime.datetime.strptime(inicio, "%Y%m%d")
     end = datetime.datetime.strptime(fim, "%Y%m%d")
     date_generated = [start + datetime.timedelta(days=x) for x in range(0, (end-start).days)]
     #print('Data inicial: ',start.strftime("%Y%m%d") ) 
     #print('Data final: ',end.strftime("%Y%m%d") ) 
     #print('Quantidade de Partições: ',len(date_generated)) 
     return date_generated

def CetusSalvaCSVS3(dataframe,nm_s3_file,s3_path):

    import s3fs
    S3fs = s3fs.S3FileSystem()

    # Nome do arquivo a ser salvo no S3
    #nm_s3_file = 'OrcamentoDespesas_'+str(dtref)+'.csv'

    # Caminho no lake (S3)
    #s3_path = 'projeto-bigdata-cetus/datalake/DespesasPublicas/'

    bytes_to_write = dataframe.to_csv(sep = ',',header=True, index=False, index_label=None).encode()
    with S3fs.open(s3_path+nm_s3_file, 'wb') as f:
        f.write(bytes_to_write)
    return print('Salvo com Sucesso :)')



def CetusReadS3CSVFile(nm_bucket,path_file,sep=','):
    import boto3
    import pandas as pd
    bucket=nm_bucket # Or whatever you called your bucket
    data_key = path_file # Where the file is within your bucket
    data_location = 's3://{}/{}'.format(bucket, data_key)
    try:
        df = pd.read_csv(data_location,sep=sep,encoding='utf-8',error_bad_lines=False) 

    except:
        df = pd.read_csv(data_location,sep=sep,encoding='latin-1',error_bad_lines=False)

    return df

# %%
# Carga histórica

# 20150118 não tem 
vetor_safras_aux = CetusRefVecDays("20150302","20150501") 
s3_path = 'projeto-bigdata-cetus/datalake/DespesasPublicas/'


anomes = []
for data_ref in vetor_safras_aux:    
    anomes.append(data_ref.strftime("%Y%m%d"))
vetor_safras = list(dict.fromkeys(anomes))

for anomes in vetor_safras:
    print('Cetus - Carga Histórica Ref ---->', anomes)
    a,b,c,d,e,f,g,h,i,j = CetusDespesasPublicas(anomes)
    
    nm_s3_file_a = 'DP_Lake_DocEmpLiqPag_Empenho_'+str(anomes)+'.csv'
    CetusSalvaCSVS3(a,nm_s3_file_a,s3_path)
    
    nm_s3_file_b = 'DP_Lake_DocEmpLiqPag_Empenho_Item_'+str(anomes)+'.csv'
    CetusSalvaCSVS3(b,nm_s3_file_b,s3_path)
    
    nm_s3_file_c = 'DP_Lake_DocEmpLiqPag_Liquidacao_'+str(anomes)+'.csv'
    CetusSalvaCSVS3(c,nm_s3_file_c,s3_path)

    nm_s3_file_d = 'DP_Lake_DocEmpLiqPag_Liquidacao_Empenho_'+str(anomes)+'.csv'
    CetusSalvaCSVS3(d,nm_s3_file_d,s3_path)

    nm_s3_file_e = 'DP_Lake_DocEmpLiqPag_Pagamento_'+str(anomes)+'.csv'
    CetusSalvaCSVS3(e,nm_s3_file_e,s3_path)

    nm_s3_file_f = 'DP_Lake_DocEmpLiqPag_Pagamento_Empenho_'+str(anomes)+'.csv'
    CetusSalvaCSVS3(f,nm_s3_file_f,s3_path)

    nm_s3_file_g = 'DP_Lake_DocEmpLiqPag_Pagamento_Listas_'+str(anomes)+'.csv'
    CetusSalvaCSVS3(g,nm_s3_file_g,s3_path)

    nm_s3_file_h = 'DP_Lake_DocEmpLiqPag_Pagamento_Favorecidos_'+str(anomes)+'.csv'
    CetusSalvaCSVS3(h,nm_s3_file_h,s3_path)

    nm_s3_file_i = 'DP_Lake_DocEmpLiqPag_Pagamento_Listas_Bancos_'+str(anomes)+'.csv'
    CetusSalvaCSVS3(i,nm_s3_file_i,s3_path)

    nm_s3_file_j = 'DP_Lake_DocEmpLiqPag_Pagamento_Listas_Precatórios_'+str(anomes)+'.csv'
    CetusSalvaCSVS3(j,nm_s3_file_j,s3_path)
# Out:
# Cetus - Carga Histórica Ref ----> 20150302
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Cetus - Carga Histórica Ref ----> 20150303
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Cetus - Carga Histórica Ref ----> 20150304
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Cetus - Carga Histórica Ref ----> 20150305
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Cetus - Carga Histórica Ref ----> 20150306
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Cetus - Carga Histórica Ref ----> 20150307
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Cetus - Carga Histórica Ref ----> 20150308
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Cetus - Carga Histórica Ref ----> 20150309
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Cetus - Carga Histórica Ref ----> 20150310
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Cetus - Carga Histórica Ref ----> 20150311
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Cetus - Carga Histórica Ref ----> 20150312
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Cetus - Carga Histórica Ref ----> 20150313
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Cetus - Carga Histórica Ref ----> 20150314
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Cetus - Carga Histórica Ref ----> 20150315
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Cetus - Carga Histórica Ref ----> 20150316
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Salvo com Sucesso :)
# Cetus - Carga Histórica Ref ----> 20150317
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-60d769c9566f> in <module>()
#      13 for anomes in vetor_safras:
#      14     print('Cetus - Carga Histórica Ref ---->', anomes)
# ---> 15     a,b,c,d,e,f,g,h,i,j = CetusDespesasPublicas(anomes)
#      16
#      17     nm_s3_file_a = 'DP_Lake_DocEmpLiqPag_Empenho_'+str(anomes)+'.csv'
#
# <ipython-input-3-c47f0c417969> in CetusDespesasPublicas(ANOMES_INFO)
#       4     #ANOMES_INFO = 20130331
#       5     import urllib.request
# ----> 6     urllib.request.urlretrieve('http://www.portaltransparencia.gov.br/download-de-dados/despesas/'+str(ANOMES_INFO), 'dados_despesaspub_' + str(ANOMES_INFO) + '.zip')
#       7
#       8     import zipfile
#
# /opt/conda/lib/python3.6/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     275
#     276             while True:
# --> 277                 block = fp.read(bs)
#     278                 if not block:
#     279                     break
#
# /opt/conda/lib/python3.6/http/client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# /opt/conda/lib/python3.6/http/client.py in readinto(self, b)
#     491         # connection, and the user is reading more bytes than will be provided
#     492         # (for example, reading in 1k chunks)
# --> 493         n = self.fp.readinto(b)
#     494         if not n and b:
#     495             # Ideally, we would raise IncompleteRead if the content-length
#
# /opt/conda/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:
